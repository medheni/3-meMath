# %% [markdown]
# <a href="https://colab.research.google.com/github/medheni/3-meMath/blob/main/LesListes_CahierDeBordDeL'enseignant.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #<font color=white>Cahier de bord de l'enseignant

# %% [markdown]
# ![01.png](data:image/png;base64,...)

# %%
#@title <font color="#70AD47" face="Cooper Std Black" size=6 > Délai de remise de votre travail


html_src = """
<script src="https://cdn.logwork.com/widget/countdown.js"></script>
<a href="https://logwork.com/countdown-2yq6" class="countdown-timer" data-timezone="Africa/Tunis" data-language="fr" data-date="2020-11-18 15:32"> <font color="#A31515" face="Berlin Sans FB Demi" size=6 >il vous reste :</font></a>


    """


import IPython
from IPython.core.display import display_html, display_javascript, Javascript
display_html(IPython.core.display.HTML(data=html_src))
# Out:
# <script src="https://cdn.logwork.com/widget/countdown.js"></script>
# <a href="https://logwork.com/countdown-2yq6" class="countdown-timer" data-timezone="Africa/Tunis" data-language="fr" data-date="2020-11-18 15:32"> <font color="#A31515" face="Berlin Sans FB Demi" size=6 >il vous reste :</font></a>

# %% [markdown]
# ![02.png](data:image/png;base64,...)

# %% [markdown]
# ![03.png](data:image/png;base64,...)

# %%
#@title <font color="#70AD47" face="Cooper Std Black" size=6 > Carte mentale { display-mode: "form" }

#@markdown <font color="#002060" face="Lucida Calligraphy" size=5>C'est un tableau blanc collaboratif, partagé entre tous les élèves de la classe.
html_src = """
    <h2><font color="#A31515" face="Berlin Sans FB Demi">Compléter cette figure par les fonctionnalités que doit offrir notre programme</h2>
    <div id="scratch1-div">
<iframe width="1200" height="700" frameborder="0" src="https://r9.whiteboardfox.com/959459-3516-8531"> </iframe>
 </div>
    """
import IPython
from IPython.core.display import display_html, display_javascript, Javascript
display_html(IPython.core.display.HTML(data=html_src))
# Out:
#     <h2><font color="#A31515" face="Berlin Sans FB Demi">Compléter cette figure par les fonctionnalités que doit offrir notre programme</h2>
#     <div id="scratch1-div">
# <iframe width="1200" height="700" frameborder="0" src="https://r9.whiteboardfox.com/959459-3516-8531"> </iframe>
#  </div>

# %% [markdown]
# # <font face="Copperplate Gothic Light" color=red>Se rappeler des listes</font>

# %% [markdown]
# ![uneliste.png](data:image/png;base64,...)

# %%
#@title <font color="#70AD47" face="Cooper Std Black" size=7> Présentation des listes { display-mode: "form" }


#@markdown <font color="#ED7D31" face="Berlin Sans FB Demi" size=5>Cette vidéo montre avec des exemples, l'essentiel de ce qu'il faut savoir sur les listes

from IPython.display import YouTubeVideo
YouTubeVideo('rf_q7nPJS1s', width=600, height=400)

# %% [markdown]
# ![04.png](data:image/png;base64,...)

# %% [markdown]
# ![05.png](data:image/png;base64,...)

# %% [markdown]
# ![06.png](data:image/png;base64,...)

# %% [markdown]
# ![07.png](data:image/png;base64,...)

# %% [markdown]
# ![08.png](data:image/png;base64,...)

# %% [markdown]
# # <font face="Copperplate Gothic Light" color=red>Activité 1</font>

# %% [markdown]
# <font face="cambria" >Ci-dessous, les notes de controle et synthèse des élèves d'une classe. Dans le but de créer un programme qui permet les gestion des notes. Un élève à commencé par créer <font color="blue" >**trois listes** </font><font color="green" >**np**</font> ,<font color="green" > **dc**</font> ,<font color="green" > **ds**</font>  qui permettent repectivement de ranger les <font color="green" >*noms et prénom*</font> , les <font color="green" >*notes de controles* </font> , <font color="green" >*de synthèses* </font> des élèves de cette classe.
#
# On vous propose les tâches suivantes:
#
# 1.   Afficher le nombre de noms et prénoms d'élèves stockés dans liste np
# 2.   Afficher la liste des noms et prénoms des élèves
# 3. Raffiner l'affichage pour afficher le numéro avec chaque nom et prénom
# 4. Corriger les erreurs de saisie dans la liste des noms et prénom
# 5. Pour uniformiser l'écriture des noms et prénoms, mettre la première
# lettre du nom et prénom en majuscule
#
#
#
# </font>

# %% [markdown]
# ![version2.jpg](data:image/jpeg;base64,...)

# %%
#@title <font color="#70AD47" face="Cooper Std Black" size=7> Exécution manuelle { display-mode: "form" }


#@markdown <font color="#ED7D31" face="Berlin Sans FB Demi" size=5>Comment les listes sont représentées en mémoire


html_src = """

  
<iframe width="1200" height="500" frameborder="0" src="https://pythontutor.com/iframe-embed.html#code=np%3D%5B'oussema','ibtihel','Emna%20A','EMNA%20B','','Oumaima','Eya','Bilel',%0A%20%20%20%20%20'Jihed','Jihen','Khdija%20A','Khdija%20B','Donia','Roua','Rouya',%0A%20%20%20%20%20'Chiheb','Chayma','ee','Farah','Mohamed%20A','mohamed%20B',%20'Marwa',%0A%20%20%20%20%20'Montaha','nour','Nayssen','hiba','hiba'%0A%20%20%20%20%20%5D%0Adc%3D%5B17.75,18.5,14.5,17.5,13.5,15.75,14.5,12,15,10.5,14.5,14,13.5,%0A%20%20%20%2015,16.5,'null',11,18,13,17,14.5,13,14,11,17.25%5D%0Ads%3D%5B19.5,19.5,13.25,17,16.25,16.25,18,13,16,12,10,18.5,15,12,14.75,%0A%20%20%20%20'null',10,19.5,12.5,17,11,11.5,12,12.25,18.5%5D&codeDivHeight=400&codeDivWidth=350&cumulative=false&curInstr=8&heapPrimitives=nevernest&origin=opt-frontend.js&py=3&rawInputLstJSON=%5B%5D&textReferences=false"> </iframe>s

    """


import IPython
from IPython.core.display import display_html, display_javascript, Javascript
display_html(IPython.core.display.HTML(data=html_src))
# Out:
#
# <iframe width="1200" height="500" frameborder="0" src="https://pythontutor.com/iframe-embed.html#code=np%3D%5B'oussema','ibtihel','Emna%20A','EMNA%20B','','Oumaima','Eya','Bilel',%0A%20%20%20%20%20'Jihed','Jihen','Khdija%20A','Khdija%20B','Donia','Roua','Rouya',%0A%20%20%20%20%20'Chiheb','Chayma','ee','Farah','Mohamed%20A','mohamed%20B',%20'Marwa',%0A%20%20%20%20%20'Montaha','nour','Nayssen','hiba','hiba'%0A%20%20%20%20%20%5D%0Adc%3D%5B17.75,18.5,14.5,17.5,13.5,15.75,14.5,12,15,10.5,14.5,14,13.5,%0A%20%20%20%2015,16.5,'null',11,18,13,17,14.5,13,14,11,17.25%5D%0Ads%3D%5B19.5,19.5,13.25,17,16.25,16.25,18,13,16,12,10,18.5,15,12,14.75,%0A%20%20%20%20'null',10,19.5,12.5,17,11,11.5,12,12.25,18.5%5D&codeDivHeight=400&codeDivWidth=350&cumulative=false&curInstr=8&heapPrimitives=nevernest&origin=opt-frontend.js&py=3&rawInputLstJSON=%5B%5D&textReferences=false"> </iframe>s

# %%
np=['oussema','ibtihel','Emna A','EMNA B','','Oumaima','Eya','Bilel',
     'Jihed','Jihen','Khdija A','Khdija B','Donia','Roua','Rouya',
     'Chiheb','Chayma','ee','Farah','Mohamed A','mohamed B', 'Marwa',
     'Montaha','nour','Nayssen','hiba','hiba'
     ]
dc=[17.75,18.5,14.5,17.5,13.5,15.75,14.5,12,15,10.5,14.5,14,13.5,
    15,16.5,'null',11,18,13,17,14.5,13,14,11,17.25]
ds=[19.5,19.5,13.25,17,16.25,16.25,18,13,16,12,10,18.5,15,12,14.75,
    'null',10,19.5,12.5,17,11,11.5,12,12.25,18.5]
#Tâche 1 :
"""Afficher le nombre de noms et prénoms d'élèves stockés dans liste np""" 


#Tâche 2 : 
"""Afficher la liste des noms et prénoms des élèves"""


#Tâche 3 : 
"""Raffiner l'affichage pour afficher le numéro avec chaque nom et prénom"""


#Tâche 4 : 
"""Corriger les erreurs de saisie dans la liste des noms et prénom
erreur 1 : L'ordre de ibtihel et oussema
erreur 2 : Erreur de saisie de l'élément ee entre chayma et farah
erreur 3 : Une chaine vide après Emna B
erreur 4 : Bilel doit être remplacé par Baya
erreur 5 : hiba se répète deux fois
erreur 6 : On a oublié l'élève mayssa son numéro est 22 au registre de la classe
erreur 7 : Afin d'avoir une liste de même type de données remplacé le mot null par 99.99"""


#Tâche 5 : 
"""Pour uniformiser l'écriture des noms et prénoms, mettre la première 
lettre du nom et prénom en majuscule"""

# %% [markdown]
# # <font face="Copperplate Gothic Light" color=red>Activité 2</font>

# %% [markdown]
# <font face="cambria" >Ci-dessous, un programme manquant. Compléter les traitements relatives aux questions écrites sous forme de commentaires. </font>
#
#
#
#
#
# </font>

# %% [markdown]
# ***Affichage désiré***

# %%
#@title
np=['Ibtihel','Oussema','Emna A','Emna B','Oumaima','Eya','Baya',
     'Jihed','Jihen','Khdija A','Khdija B','Donia','Roua','Rouya',
     'Chiheb','Chayma','Farah','Mohamed A','Mohamed B', 'Marwa',
     'Montaha','Mayssa','Nour','Nayssen','Hiba'
     ]
dc=[17.75,18.5,14.5,17.5,13.5,15.75,14.5,12,15,10.5,14.5,14,13.5,
    15,16.5,99.99,11,18,13,17,14.5,13,14,11,17.25]
ds=[19.5,19.5,13.25,17,16.25,16.25,18,13,16,12,10,18.5,15,12,14.75,
    99.99,10,19.5,12.5,17,11,11.5,12,12.25,18.5]
#Question 1 :
"""Afficher toutes les valeurs des listes 
chaque ligne respectera le format suivant
Numéro | Nom et prénom | Note de controle | Note de synthèse""" 

#Question 2 :
"""Raffiner l'affichage de la ligne précédente en utilisant la fonction format"""

for i in range(len(np)):
    print('{:<2}'.format(i+1),"|",'{:<10}'.format(np[i]),"|",'{:<5}'.format(dc[i]),"|",'{:<5}'.format(ds[i]))
# Out:
# 1  | Ibtihel    | 17.75 | 19.5
# 2  | Oussema    | 18.5  | 19.5
# 3  | Emna A     | 14.5  | 13.25
# 4  | Emna B     | 17.5  | 17
# 5  | Oumaima    | 13.5  | 16.25
# 6  | Eya        | 15.75 | 16.25
# 7  | Baya       | 14.5  | 18
# 8  | Jihed      | 12    | 13
# 9  | Jihen      | 15    | 16
# 10 | Khdija A   | 10.5  | 12
# 11 | Khdija B   | 14.5  | 10
# 12 | Donia      | 14    | 18.5
# 13 | Roua       | 13.5  | 15
# 14 | Rouya      | 15    | 12
# 15 | Chiheb     | 16.5  | 14.75
# 16 | Chayma     | 99.99 | 99.99
# 17 | Farah      | 11    | 10
# 18 | Mohamed A  | 18    | 19.5
# 19 | Mohamed B  | 13    | 12.5
# 20 | Marwa      | 17    | 17
# 21 | Montaha    | 14.5  | 11
# 22 | Mayssa     | 13    | 11.5
# 23 | Nour       | 14    | 12
# 24 | Nayssen    | 11    | 12.25
# 25 | Hiba       | 17.25 | 18.5

# %% [markdown]
# ***Compléter le code pour obtenir le même affichage ci-dessus:***

# %%
np=['Ibtihel','Oussema','Emna A','Emna B','Oumaima','Eya','Baya',
     'Jihed','Jihen','Khdija A','Khdija B','Donia','Roua','Rouya',
     'Chiheb','Chayma','Farah','Mohamed A','Mohamed B', 'Marwa',
     'Montaha','Mayssa','Nour','Nayssen','Hiba'
     ]
dc=[17.75,18.5,14.5,17.5,13.5,15.75,14.5,12,15,10.5,14.5,14,13.5,
    15,16.5,99.99,11,18,13,17,14.5,13,14,11,17.25]
ds=[19.5,19.5,13.25,17,16.25,16.25,18,13,16,12,10,18.5,15,12,14.75,
    99.99,10,19.5,12.5,17,11,11.5,12,12.25,18.5]
#Tâche 1 :
"""Afficher toutes les valeurs des listes 
chaque ligne respectera le format suivant
Numéro | Nom et prénom | Note de controle | Note de synthèse""" 

#Tâche 2 :
"""Raffiner l'affichage de la ligne précédente en utilisant la fonction format"""

# %% [markdown]
# # <font face="Copperplate Gothic Light" color=red>Activité 3</font>

# %% [markdown]
# <font face="cambria" >Ci-dessous, un programme manquant. Compléter les traitements relatives aux questions écrites sous forme de commentaires. </font>

# %%
np=['Ibtihel','Oussema','Emna A','Emna B','Oumaima','Eya','Baya',
     'Jihed','Jihen','Khdija A','Khdija B','Donia','Roua','Rouya',
     'Chiheb','Chayma','Farah','Mohamed A','Mohamed B', 'Marwa',
     'Montaha','Mayssa','Nour','Nayssen','Hiba'
     ]
dc=[17.75,18.5,14.5,17.5,13.5,15.75,14.5,12,15,10.5,14.5,14,13.5,
    15,16.5,99.99,11,18,13,17,14.5,13,14,11,17.25]
ds=[19.5,19.5,13.25,17,16.25,16.25,18,13,16,12,10,18.5,15,12,14.75,
    99.99,10,19.5,12.5,17,11,11.5,12,12.25,18.5]
#Tâche 1 :
"""Afin de faciliter les traitements supprimer les informations de l'élève qui a 99.99"""

#Tâche 2 :
"""Créer une liste nommée moy contenant la moyenne de chaque élève"""


#Tâche 3 :
"""Afficher toutes les listes
chaque ligne respectera le format suivant
Numéro | Nom et prénom | Note de controle | Note de synthèse | Moyenne """

# %%
#Tâche 4 :
"""Déterminer la meilleure moyenne de la classe"""

#Tâche 5 :
"""Afficher le(s) nom(s) et prénom(s) de(s) élève(s) ayant la meilleure moyenne de la classe"""

# %%
#Tâche 6 :
"""Déterminer la mauvaise moyenne de la classe"""

#Tâche 7 :
"""Afficher le(s) nom(s) et prénom(s) de(s) élève(s) ayant la mauvaise moyenne de la classe"""

# %%
#Tâche 8 :
"""Afficher la note contrôle minimale et la note maximale"""

#Tâche 9 :
"""Afficher la note synthèse minimale et la note maximale"""

# %%
#Tâche 10 :
"""Afficher la liste des noms et prénoms des élèves admis ainsi que leurs moyenne """



#Tâche 11 :
""" Calculer puis afficher la moyenne de la classe """


#Tâche 12 :
""" Afficher les moyennes et les noms et prénoms des élèves
ayant une moyenne supérieure à la moyenne de la classe """

# %% [markdown]
# # <font face="Copperplate Gothic Light" color=red>Activité 4</font>

# %% [markdown]
# <font face="cambria" >Ci-dessous, un programme manquant. Compléter les traitements relatives aux questions écrites sous forme de commentaires. </font>

# %%
np=['Ibtihel','Oussema','Emna A','Emna B','Oumaima','Eya','Baya',
     'Jihed','Jihen','Khdija A','Khdija B','Donia','Roua','Rouya',
     'Chiheb','Farah','Mohamed A','Mohamed B', 'Marwa',
     'Montaha','Mayssa','Nour','Nayssen','Hiba'
     ]
dc=[17.75,18.5,14.5,17.5,13.5,15.75,14.5,12,15,10.5,14.5,14,13.5,
    15,16.5,11,18,13,17,14.5,13,14,11,17.25]
ds=[19.5,19.5,13.25,17,16.25,16.25,18,13,16,12,10,18.5,15,12,14.75,
    10,19.5,12.5,17,11,11.5,12,12.25,18.5]
"""Créer une liste nommée moy contenant la moyenne de chaque élève"""
moy=[]
for i in range(len(np)):
    moy.append((dc[i]+ds[i]*2)/3)
"""Afficher toutes les listes"""
for i in range(len(np)):
    print('{:<2}'.format(i+1),"|",'{:<10}'.format(np[i]),"|",'{:<5}'.format(dc[i]),"|",'{:<5}'.format(ds[i]),"|",'{:<5.2f}'.format(moy[i]))
#Tâche 1 :
"""Calculer puis afficher le nombre d'élèves passables (10<= moyenne<12)"""

#Tâche 2 :
"""Afficher Nom et prénom | Note de controle | Note de synthèse 
des élèves qui ont fait une amélioration au synthèse de plus de 2 points
afficher aussi le pourcentage = nombre d'élèves en amelioration / nombre total d'élèves*100"""

# %%
#Tâche 3 :
"""Afficher Nom et prénom | Note de controle | Note de synthèse 
des élèves qui ont fait une chute au synthèse de plus de 3 points"""

#Tâche 4 :
"""Créer une liste nommée ment contenant la mention de chaque élève
Afficher Nom et prénom | Mention"""

# %% [markdown]
# # <font face="Copperplate Gothic Light" color=red>Activité 5</font>

# %% [markdown]
# <font face="cambria" >Ajouter d'autres fonctionnalités à notre programme</font>
#
#
#
#
#
# </font>

# %%
np=['Ibtihel','Oussema','Emna A','Emna B','Oumaima','Eya','Baya',
     'Jihed','Jihen','Khdija A','Khdija B','Donia','Roua','Rouya',
     'Chiheb','Farah','Mohamed A','Mohamed B', 'Marwa',
     'Montaha','Mayssa','Nour','Nayssen','Hiba'
     ]
dc=[17.75,18.5,14.5,17.5,13.5,15.75,14.5,12,15,10.5,14.5,14,13.5,
    15,16.5,11,18,13,17,14.5,13,14,11,17.25]
ds=[19.5,19.5,13.25,17,16.25,16.25,18,13,16,12,10,18.5,15,12,14.75,
    10,19.5,12.5,17,11,11.5,12,12.25,18.5]

# %% [markdown]
# # <font face="Copperplate Gothic Light" color=red>Liste de listes</font>

# %% [markdown]
# <font face="cambria" >Ci-dessous, un programme manquant. Compléter les traitements relatives aux questions écrites sous forme de commentaires. </font>

# %%
np=['Ibtihel','Oussema','Emna A','Emna B','Oumaima','Eya','Baya',
     'Jihed','Jihen','Khdija A','Khdija B','Donia','Roua','Rouya',
     'Chiheb','Farah','Mohamed A','Mohamed B', 'Marwa',
     'Montaha','Mayssa','Nour','Nayssen','Hiba'
     ]
dc=[17.75,18.5,14.5,17.5,13.5,15.75,14.5,12,15,10.5,14.5,14,13.5,
    15,16.5,11,18,13,17,14.5,13,14,11,17.25]
ds=[19.5,19.5,13.25,17,16.25,16.25,18,13,16,12,10,18.5,15,12,14.75,
    10,19.5,12.5,17,11,11.5,12,12.25,18.5]
classe=[np,dc,ds]
print(len(classe))
"""Afficher toutes les listes"""
for i in range(len(classe[0])):
    print('{:<2}'.format(i+1),"|",'{:<10}'.format(classe[0][i]),"|",'{:<5}'.format(classe[1][i]),"|",'{:<5}'.format(classe[2][i]),"|")
#Tâche 1 :
"""Etendre la classe par une liste contenant la moyenne"""

classe.append([])
for i in range(len(np)):
    classe[3].append((dc[i]+ds[i]*2)/3)

"""Afficher toutes les listes"""
for i in range(len(classe[0])):
    print('{:<2}'.format(i+1),"|",'{:<10}'.format(classe[0][i]),"|",'{:<5}'.format(classe[1][i]),"|",'{:<5}'.format(classe[2][i]),"|",'{:<5.2f}'.format(classe[3][i]))

# %%
#@title


html_src = """
    <h2>Exécution manuelle</h2>
<iframe width="1000" height="500" frameborder="0" src="https://pythontutor.com/iframe-embed.html#code=np%3D%5B'Ibtihel','Oussema','Emna%20A','Emna%20B','Oumaima','Eya','Baya',%0A%20%20%20%20%20'Jihed','Jihen','Khdija%20A','Khdija%20B','Donia','Roua','Rouya',%0A%20%20%20%20%20'Chiheb','Farah','Mohamed%20A','Mohamed%20B',%20'Marwa',%0A%20%20%20%20%20'Montaha','Mayssa','Nour','Nayssen','Hiba'%0A%20%20%20%20%20%5D%0Adc%3D%5B17.75,18.5,14.5,17.5,13.5,15.75,14.5,12,15,10.5,14.5,14,13.5,%0A%20%20%20%2015,16.5,11,18,13,17,14.5,13,14,11,17.25%5D%0Ads%3D%5B19.5,19.5,13.25,17,16.25,16.25,18,13,16,12,10,18.5,15,12,14.75,%0A%20%20%20%2010,19.5,12.5,17,11,11.5,12,12.25,18.5%5D%0Aclasse%3D%5Bnp,dc,ds%5D%0Aprint%28len%28classe%29%29%0A%22%22%22Afficher%20toutes%20les%20listes%22%22%22%0Afor%20i%20in%20range%28len%28classe%5B0%5D%29%29%3A%0A%20%20%20%20print%28'%7B%3A%3C2%7D'.format%28i%2B1%29,%22%7C%22,'%7B%3A%3C10%7D'.format%28classe%5B0%5D%5Bi%5D%29,%22%7C%22,'%7B%3A%3C5%7D'.format%28classe%5B1%5D%5Bi%5D%29,%22%7C%22,'%7B%3A%3C5%7D'.format%28classe%5B2%5D%5Bi%5D%29,%22%7C%22%29%0A%23T%C3%A2che%201%20%3A%0A%22%22%22Etendre%20la%20classe%20par%20une%20liste%20contenant%20la%20moyenne%22%22%22%0A%0Aclasse.append%28%5B%5D%29%0Afor%20i%20in%20range%28len%28np%29%29%3A%0A%20%20%20%20classe%5B3%5D.append%28%28dc%5Bi%5D%2Bds%5Bi%5D*2%29/3%29%0A%0A%22%22%22Afficher%20toutes%20les%20listes%22%22%22%0Afor%20i%20in%20range%28len%28classe%5B0%5D%29%29%3A%0A%20%20%20%20print%28'%7B%3A%3C2%7D'.format%28i%2B1%29,%22%7C%22,'%7B%3A%3C10%7D'.format%28classe%5B0%5D%5Bi%5D%29,%22%7C%22,'%7B%3A%3C5%7D'.format%28classe%5B1%5D%5Bi%5D%29,%22%7C%22,'%7B%3A%3C5%7D'.format%28classe%5B2%5D%5Bi%5D%29,%22%7C%22,'%7B%3A%3C5.2f%7D'.format%28classe%5B3%5D%5Bi%5D%29%29%0A%0A&codeDivHeight=400&codeDivWidth=350&cumulative=false&curInstr=158&heapPrimitives=nevernest&origin=opt-frontend.js&py=3&rawInputLstJSON=%5B%5D&textReferences=false"> </iframe>
    """


import IPython
from IPython.core.display import display_html, display_javascript, Javascript
display_html(IPython.core.display.HTML(data=html_src))
# Out:
#     <h2>Exécution manuelle</h2>
# ...

# %% [markdown]
# #Divers

# %%
#@title <font color="#70AD47" face="Cooper Std Black" size=7> Quiz
html_src = """
<iframe src="https://docs.google.com/forms/d/e/1FAIpQLSeaNCT_9Y4wAjBqPNe7fzcv6BzDEOVpAQpRAMGa0Rf8MFQL4A/viewform?embedded=true" width="640" height="2050" frameborder="0" marginheight="0" marginwidth="0">Chargement…</iframe>
    """
import IPython
from IPython.core.display import display_html, display_javascript, Javascript
display_html(IPython.core.display.HTML(data=html_src))
# Out:
# <iframe src="https://docs.google.com/forms/d/e/1FAIpQLSeaNCT_9Y4wAjBqPNe7fzcv6BzDEOVpAQpRAMGa0Rf8MFQL4A/viewform?embedded=true" width="640" height="2050" frameborder="0" marginheight="0" marginwidth="0">Chargement…</iframe>

# %%
#@title <font color="#70AD47" face="Cooper Std Black" size=7> Agenda de la classe { display-mode: "form" }



html_src = """
  
 
<iframe src="https://calendar.google.com/calendar/embed?src=classroom115347186197945259239%40group.calendar.google.com&ctz=Africa%2FTunis" style="border: 0" width="800" height="600" frameborder="0" scrolling="no"></iframe>

    """
import IPython
from IPython.core.display import display_html, display_javascript, Javascript
display_html(IPython.core.display.HTML(data=html_src))
# Out:
#
#
# <iframe src="https://calendar.google.com/calendar/embed?src=classroom115347186197945259239%40group.calendar.google.com&ctz=Africa%2FTunis" style="border: 0" width="800" height="600" frameborder="0" scrolling="no"></iframe>
